# -1.380124596348935445e-03
# -2.310167592859787428e-03
# -3.595560151927829073e-03
# -5.173117897662348613e-03
# -6.843195854373550907e-03
# -8.248190465171625907e-03
# 4.986947073734956937e-02

# %%
# make the matrix
# call simpledrift to fill in the values for different drift and bh
# pass on to heatmap
# pay attention to axes so they give the correct values
import numpy as np
import matplotlib.pyplot as plt
import simpledrift as sd
import math
from joblib import Parallel, delayed
import os
import csv

def csvgraph(driftvariance, betadvantage):

    csv = csv.reader(open('Matrices/da'+ str(driftvariance)+'ba'+ str(betadvantage)+'.csv','r'))
    line_count = 1
    for row in csv:
        if line_count == 1:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            print(f'For day {row[0]}, the da was {row[1]}, and the bh was {row[2]}.')
            line_count += 1
    matrix=np.zeros((numberofdays, 3))
    print(matrix)
    print(f'Processed {line_count} lines.')

#     # figuresavepath='figs'
#     # prefvariance=np.linspace(bhlower, bhupper, bhinterval)
#     # driftvariance=np.linspace(driftlower, driftupper, driftinterval)

#     numruns=bhinterval*driftinterval

#     #testing values are right
#     # for n in range(numruns):
#     #     print('driftvariance'+str(driftvariance[math.floor(n/bhinterval)])+ 'prefvariance'+ str(prefvariance[n%bhinterval]))

#     flatmatrix=np.zeros(numruns)

#     # for x in range(bhinterval):
#     flatmatrix[:]=Parallel(n_jobs=-1, verbose=10)(delayed(matrix for n in range(numruns)))
#             # print(["Drift is: ", driftvariance[y], "Bet-hedging is: ", driftvariance[x]] )
#             # print(matrix)
#     print(flatmatrix)

#     # flatmatrix=np.matrix(flatmatrix)
#     # flatmatrix=
#     matrix=np.zeros((bhinterval,driftinterval))
#     matrix[:,:]=flatmatrix.reshape((bhinterval, driftinterval), order='F')
#     matrixlog=np.log(matrix)
#     print(matrixlog)
#     print(matrix)



#     bhmargin=(bhupper-bhlower)/(bhinterval-1)/2
#     driftmargin=(driftupper-driftlower)/(driftinterval-1)/2
#     prefvariancemesh=np.linspace(bhlower-bhmargin, bhupper+bhmargin, bhinterval+1)
#     driftvariancemesh=np.linspace(driftlower-driftmargin, driftupper+driftmargin, driftinterval+1)
#     print(prefvariancemesh)
#     print(driftvariancemesh)

# # driftvariancegrid2, prefvariancegrid2= np.meshgrid(driftvariance, prefvariance)

#     # print(matrix)

#     fig,ax=plt.subplots()
#     scale=max(-np.min(matrixlog),np.max(matrixlog))
#     c=ax.pcolormesh(driftvariancemesh, prefvariancemesh, matrixlog, shading='flat', cmap='RdBu',  vmin=-scale, vmax=scale)


#     # c=ax.pcolormesh(driftvariancemesh, prefvariancemesh, matrixlog, shading='flat', cmap='RdBu',  vmin=-20, vmax=20)
#     ax.set_xlabel('Drift')
#     ax.set_ylabel('Bet-Hedging')
#     fig.colorbar(c, ax=ax)
#     ax.set_title('Log of Final Population')
#     plt.show

#     if os.path.exists(figuresavepath):
#         fig.savefig(os.path.join(figuresavepath,'heatmap.png'),bbox_inches='tight', pad_inches=.3)
#         print(figuresavepath)
#     else:
#         print('not saving, no valid path')

#     return matrix, driftvariance, prefvariance

# %%
csvgraph(.2,0.0)
# Out:
# Column names are # Each row is one day
# For day #  Day, the da was  Drift Advantage, and the bh was  Bet Advantage.
# For day 0, the da was  0.0000e+00, and the bh was  0.0000e+00.
# For day 1, the da was  -1.9748e-01, and the bh was  0.0000e+00.
# For day 2, the da was  -8.9502e-02, and the bh was  0.0000e+00.
# For day 3, the da was  -5.0966e-02, and the bh was  0.0000e+00.
# For day 4, the da was  -3.1246e-02, and the bh was  0.0000e+00.
# For day 5, the da was  -1.9656e-02, and the bh was  0.0000e+00.
# For day 6, the da was  -1.2512e-02, and the bh was  0.0000e+00.
# For day 7, the da was  -8.0188e-03, and the bh was  0.0000e+00.
# For day 8, the da was  -5.1666e-03, and the bh was  0.0000e+00.
# For day 9, the da was  -3.3389e-03, and the bh was  0.0000e+00.
# For day 10, the da was  -2.1625e-03, and the bh was  0.0000e+00.
# For day 11, the da was  -1.4005e-03, and the bh was  0.0000e+00.
# For day 12, the da was  2.9355e-02, and the bh was  0.0000e+00.
# For day 13, the da was  2.1210e-03, and the bh was  0.0000e+00.
# For day 14, the da was  -1.7823e-02, and the bh was  0.0000e+00.
# For day 15, the da was  -2.7530e-02, and the bh was  0.0000e+00.
# For day 16, the da was  -3.0122e-02, and the bh was  0.0000e+00.
# For day 17, the da was  -2.8275e-02, and the bh was  0.0000e+00.
# For day 18, the da was  -2.3891e-02, and the bh was  0.0000e+00.
# For day 19, the da was  -1.8528e-02, and the bh was  0.0000e+00.
# For day 20, the da was  -1.3359e-02, and the bh was  0.0000e+00.
# For day 21, the da was  -9.0782e-03, and the bh was  0.0000e+00.
# For day 22, the da was  -5.9234e-03, and the bh was  0.0000e+00.
# For day 23, the da was  -1.2644e-02, and the bh was  0.0000e+00.
# For day 24, the da was  -1.2397e-02, and the bh was  0.0000e+00.
# For day 25, the da was  -9.1758e-03, and the bh was  0.0000e+00.
# For day 26, the da was  -6.2734e-03, and the bh was  0.0000e+00.
# For day 27, the da was  -4.5262e-03, and the bh was  0.0000e+00.
# For day 28, the da was  -3.6898e-03, and the bh was  0.0000e+00.
# For day 29, the da was  -3.3643e-03, and the bh was  0.0000e+00.
# For day 30, the da was  -3.2640e-03, and the bh was  0.0000e+00.
# For day 31, the da was  -3.2531e-03, and the bh was  0.0000e+00.
# For day 32, the da was  -3.2758e-03, and the bh was  0.0000e+00.
# For day 33, the da was  -3.2885e-03, and the bh was  0.0000e+00.
# For day 34, the da was  -1.6447e-03, and the bh was  0.0000e+00.
# For day 35, the da was  -4.0091e-03, and the bh was  0.0000e+00.
# For day 36, the da was  -1.0819e-02, and the bh was  0.0000e+00.
# For day 37, the da was  -1.9328e-02, and the bh was  0.0000e+00.
# For day 38, the da was  -2.6112e-02, and the bh was  0.0000e+00.
# For day 39, the da was  -2.8969e-02, and the bh was  0.0000e+00.
# For day 40, the da was  -2.7621e-02, and the bh was  0.0000e+00.
# For day 41, the da was  -2.3338e-02, and the bh was  0.0000e+00.
# For day 42, the da was  -1.7952e-02, and the bh was  0.0000e+00.
# For day 43, the da was  -1.2903e-02, and the bh was  0.0000e+00.
# For day 44, the da was  -8.8794e-03, and the bh was  0.0000e+00.
# For day 45, the da was  -6.0727e-03, and the bh was  0.0000e+00.
# For day 46, the da was  -3.6848e-03, and the bh was  0.0000e+00.
# For day 47, the da was  -1.5148e-03, and the bh was  0.0000e+00.
# For day 48, the da was  1.4847e-04, and the bh was  0.0000e+00.
# For day 49, the da was  9.9919e-04, and the bh was  0.0000e+00.
# For day 50, the da was  9.5098e-04, and the bh was  0.0000e+00.
# For day 51, the da was  6.8266e-05, and the bh was  0.0000e+00.
# For day 52, the da was  -1.4706e-03, and the bh was  0.0000e+00.
# For day 53, the da was  -3.4430e-03, and the bh was  0.0000e+00.
# For day 54, the da was  -5.5663e-03, and the bh was  0.0000e+00.
# For day 55, the da was  -7.5064e-03, and the bh was  0.0000e+00.
# For day 56, the da was  -9.0623e-03, and the bh was  0.0000e+00.
# For day 57, the da was  -1.0681e-02, and the bh was  0.0000e+00.
# For day 58, the da was  -1.2693e-02, and the bh was  0.0000e+00.
# For day 59, the da was  -1.4755e-02, and the bh was  0.0000e+00.
# For day 60, the da was  -1.5991e-02, and the bh was  0.0000e+00.
# For day 61, the da was  -1.5694e-02, and the bh was  0.0000e+00.
# For day 62, the da was  -1.3856e-02, and the bh was  0.0000e+00.
# For day 63, the da was  -1.1078e-02, and the bh was  0.0000e+00.
# For day 64, the da was  -8.1156e-03, and the bh was  0.0000e+00.
# For day 65, the da was  -5.5450e-03, and the bh was  0.0000e+00.
# For day 66, the da was  -3.6019e-03, and the bh was  0.0000e+00.
# For day 67, the da was  -2.2172e-03, and the bh was  0.0000e+00.
# For day 68, the da was  -1.1813e-03, and the bh was  0.0000e+00.
# For day 69, the da was  -3.5032e-04, and the bh was  0.0000e+00.
# For day 70, the da was  2.7995e-04, and the bh was  0.0000e+00.
# For day 71, the da was  5.8054e-04, and the bh was  0.0000e+00.
# For day 72, the da was  3.7766e-04, and the bh was  0.0000e+00.
# For day 73, the da was  -4.9341e-04, and the bh was  0.0000e+00.
# For day 74, the da was  -2.0980e-03, and the bh was  0.0000e+00.
# For day 75, the da was  -4.3364e-03, and the bh was  0.0000e+00.
# For day 76, the da was  -6.8662e-03, and the bh was  0.0000e+00.
# For day 77, the da was  -9.1740e-03, and the bh was  0.0000e+00.
# For day 78, the da was  -1.0721e-02, and the bh was  0.0000e+00.
# For day 79, the da was  -1.1260e-02, and the bh was  0.0000e+00.
# For day 80, the da was  -1.0885e-02, and the bh was  0.0000e+00.
# For day 81, the da was  -9.8744e-03, and the bh was  0.0000e+00.
# For day 82, the da was  -8.5065e-03, and the bh was  0.0000e+00.
# For day 83, the da was  -6.9678e-03, and the bh was  0.0000e+00.
# For day 84, the da was  -5.3829e-03, and the bh was  0.0000e+00.
# For day 85, the da was  -3.8842e-03, and the bh was  0.0000e+00.
# For day 86, the da was  -2.5783e-03, and the bh was  0.0000e+00.
# For day 87, the da was  -1.5455e-03, and the bh was  0.0000e+00.
# For day 88, the da was  -8.2744e-04, and the bh was  0.0000e+00.
# For day 89, the da was  -4.2498e-04, and the bh was  0.0000e+00.
# For day 90, the da was  -2.9957e-04, and the bh was  0.0000e+00.
# For day 91, the da was  -4.1819e-04, and the bh was  0.0000e+00.
# For day 92, the da was  -7.6792e-04, and the bh was  0.0000e+00.
# For day 93, the da was  -1.3801e-03, and the bh was  0.0000e+00.
# For day 94, the da was  -2.3102e-03, and the bh was  0.0000e+00.
# For day 95, the da was  -3.5956e-03, and the bh was  0.0000e+00.
# For day 96, the da was  -5.1731e-03, and the bh was  0.0000e+00.
# For day 97, the da was  -6.8432e-03, and the bh was  0.0000e+00.
# For day 98, the da was  -8.2482e-03, and the bh was  0.0000e+00.
# For day 0, the da was  4.9869e-02, and the bh was  0.0000e+00.
# Processed 103 lines.
